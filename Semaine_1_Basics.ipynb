# %%
# Jour 1: Ma première action financière!

prix_action = 1500
quantite = 10
total = prix_action * quantite

print(f"J'ai acheté {quantite} actions")
print(f"Au prix de {prix_action} FCFA chacune")
print(f"Total investi: {total} FCFA")
# Out:
# J'ai acheté 10 actions
# Au prix de 1500 FCFA chacune
# Total investi: 15000 FCFA
